# %%
import pandas as pd

df = pd.read_json('pathway.json')

df
# Out:
#                                                                                         1. Metabolism  \
# 1.0 Global and overview maps                        [01100, 01110, 01120, 01200, 01210, 01212, 012...
# 1.1 Carbohydrate metabolism                         [00010, 00020, 00030, 00040, 00051, 00052, 000...
# 1.2 Energy metabolism                               [00190, 00195, 00196, 00710, 00720, 00680, 009...
# 1.3 Lipid metabolism                                [00061, 00062, 00071, 00073, 00100, 00120, 001...
# 1.4 Nucleotide metabolism                                                              [00230, 00240]
# 1.5 Amino acid metabolism                           [00250, 00260, 00270, 00280, 00290, 00300, 003...
# 1.6 Metabolism of other amino acids                 [00410, 00430, 00440, 00450, 00460, 00470, 00480]
# 1.7 Glycan biosynthesis and metabolism              [00510, 00513, 00512, 00515, 00514, 00532, 005...
# ...
